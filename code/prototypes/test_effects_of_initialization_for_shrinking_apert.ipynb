# %%
# %matplotlib inline
# %autoreload 2

# %%
from __future__ import division

# %%
import matplotlib.pyplot as plt
import sys
sys.path.append("../")
sys.path.append("../analyses/")

# %%
import compare_methods as compare

# %%
from get_gal_centroids import shrinking_apert

# %%
bimodal_data = compare.dumbbell_data()

# %%
plt.axes().set_aspect('equal')
plt.plot(bimodal_data[:, 0], bimodal_data[:, 1], 'k.',
         alpha=0.5)

# %%
try_center = [[i, i] for i in np.arange(-3, 3, 0.5)]

# %%
try_center
# Out:
# [[-3.0, -3.0],
#  [-2.5, -2.5],
#  [-2.0, -2.0],
#  [-1.5, -1.5],
#  [-1.0, -1.0],
#  [-0.5, -0.5],
#  [0.0, 0.0],
#  [0.5, 0.5],
#  [1.0, 1.0],
#  [1.5, 1.5],
#  [2.0, 2.0],
#  [2.5, 2.5]]

# %%
shrink_peaks = np.array([shrinking_apert(bimodal_data, center_coord=cent)
                        for cent in try_center])

# %%
# shrink_peaks

# %%
plt.axes().set_aspect('equal')
plt.plot(bimodal_data[:, 0], bimodal_data[:, 1], 'k.',
         alpha=0.5, label="bimodal data")
plt.plot(shrink_peaks[:, 0], shrink_peaks[:, 1], 'rx',
         label="shrinking aperture peak variation",
         mew=2)

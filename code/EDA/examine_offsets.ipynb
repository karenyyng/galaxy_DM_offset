# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
# %matplotlib inline

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
import pickle
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr as PearsonR
import sys
import h5py
from matplotlib.mlab import bivariate_normal

# %%
sys.path.append("../")

# %%
import plot_gal_prop as pg
import extract_catalog as ec

# %%
offset_list = np.array(pickle.load(open('offset_list_129_testing.pkl')))
relaxedness_list = np.array(pickle.load(open('relaxedness_129_testing.pkl')))
fhat_list = pickle.load(open('fhat_129.pkl'))

# %%
fhat_list[0].keys()
# Out:
# ['gridtype',
#  'bandwidth_matrix_H',
#  'eval_points',
#  'gridded',
#  'domPeaks',
#  'peak_coords_ix',
#  'weight_w',
#  'binned',
#  'names',
#  'estimate',
#  'data_x',
#  'domPeak']

# %%
ixes = fhat_list[0]["peak_coords_ix"] - 1

# %%
eval_points1 = fhat_list[0]["eval_points"][0]
eval_points2 = fhat_list[0]["eval_points"][1]

# %%
f = h5py.File("../../data/Illustris-1_fof_subhalo_myCompleteHaloCatalog_00135.hdf5")

# %%
R200C = f["Group"]["Group_R_Crit200"][:129]

# %%
_, _, _ = plt.hist(offset_list[:, 0], normed=True, range=(0, 2e3),
                   bins=30)
plt.title('KDE peak offset in c kpc/h')
plt.xlabel('offset in c kpc/h')

# %%
# !open ../plots

# %%
_, _, _ = plt.hist(offset_list[:, 1],
                   bins=50)
plt.xlabel('KDE peak offset in fraction of R200C')
plt.ylabel('Number of clusters')
plt.savefig('../plots/KDE_peak_mostBound_offset_full_range.png', 
            bbox_inches='tight', dpi=150)

# %%
_, _, _ = plt.hist(offset_list[:, 1], normed=True,
                   bins=50, range=(0, 10))
plt.title("No of cluster with offset < 0.5 * R200C is {0}".format(np.sum(mask)))
plt.xlabel('KDE peak offset in fraction of R200C')
plt.ylabel('PDF')
plt.savefig('../plots/KDE_peak_mostBound_offset_zoomed.png', 
            bbox_inches='tight', dpi=150)

# %%
np.sum(mask) / 129.
# Out:
# 0.023255813953488372

# %%
#_, _, _ = plt.hist(relaxedness_list[mask], histtype='step',
#                   label='offset > 10%')
_, _, _ = plt.hist(relaxedness_list[~mask], histtype='step', color='r',
                   label='offset < 10%')
plt.title('clusters')
plt.xlabel('galaxy-most bound particle offset in terms % of R200C')
plt.ylabel('number of clusters')
plt.legend(loc='best')
plt.savefig('../plots/why_huge_offset.png',
            bbox_inches='tight')

# %% [markdown]
# Look at the correlation of the relaxedness and the offset in R200C

# %%
pearsonr, pvalue = PearsonR(relaxedness_list, offset_list[:, 1])

# %%
print "pearson R coefficient is {0}".format(pearsonr)
print "p value is ... {0}".format(pvalue)
# Out:
# pearson R coefficient is 0.468935141038
# p value is ... 2.08151989648e-08

# %%
# !open ../plots/

# %%
#plt.semilogy(relaxedness_list, offset_list[:, 0], 'r.', alpha=0.7)
plt.semilogy(relaxedness_list, offset_list[:, 1], 'b.', alpha=0.7)
plt.xlabel("non-relaxedness criteria 1")
plt.ylabel("offset in terms of R200C")
plt.title("Pearson R correlation for data " + 
          "= {0:.2f}".format(pearsonr))
plt.savefig("../plots/relaxednessVSOffsetInR200C.png", 
            bbox_inches="tight", dpi=200)

# %% [markdown]
# not very correlated ...

# %% [markdown]
# # Look at the KDE maps from ks_KDE.r

# %%
fhat_dict = pickle.load(open('fhat_129.pkl', 'r'))

# %%
fhat_dict[0].keys()
# Out:
# ['gridtype',
#  'bandwidth_matrix_H',
#  'data_x',
#  'gridded',
#  'weight_w',
#  'binned',
#  'names',
#  'domPeak',
#  'eval_points',
#  'estimate']

# %%
fhat = fhat_dict[0]

# %%
fhat["eval_points"][]
# Out:
# array([ -2.16768390e+03,  -2.14123885e+03,  -2.11479380e+03,
#         -2.08834875e+03,  -2.06190370e+03,  -2.03545865e+03,
#         -2.00901360e+03,  -1.98256855e+03,  -1.95612350e+03,
#         -1.92967844e+03,  -1.90323339e+03,  -1.87678834e+03,
#         -1.85034329e+03,  -1.82389824e+03,  -1.79745319e+03,
#         -1.77100814e+03,  -1.74456309e+03,  -1.71811804e+03,
#         -1.69167299e+03,  -1.66522794e+03,  -1.63878289e+03,
#         -1.61233784e+03,  -1.58589279e+03,  -1.55944774e+03,
#         -1.53300269e+03,  -1.50655764e+03,  -1.48011259e+03,
#         -1.45366754e+03,  -1.42722249e+03,  -1.40077744e+03,
#         -1.37433239e+03,  -1.34788733e+03,  -1.32144228e+03,
#         -1.29499723e+03,  -1.26855218e+03,  -1.24210713e+03,
#         -1.21566208e+03,  -1.18921703e+03,  -1.16277198e+03,
#         -1.13632693e+03,  -1.10988188e+03,  -1.08343683e+03,
#         -1.05699178e+03,  -1.03054673e+03,  -1.00410168e+03,
#         -9.77656628e+02,  -9.51211578e+02,  -9.24766527e+02,
#         -8.98321477e+02,  -8.71876427e+02,  -8.45431376e+02,
#         -8.18986326e+02,  -7.92541275e+02,  -7.66096225e+02,
#         -7.39651174e+02,  -7.13206124e+02,  -6.86761073e+02,
#         -6.60316023e+02,  -6.33870972e+02,  -6.07425922e+02,
#         -5.80980872e+02,  -5.54535821e+02,  -5.28090771e+02,
#         -5.01645720e+02,  -4.75200670e+02,  -4.48755619e+02,
#         -4.22310569e+02,  -3.95865518e+02,  -3.69420468e+02,
#         -3.42975417e+02,  -3.16530367e+02,  -2.90085317e+02,
#         -2.63640266e+02,  -2.37195216e+02,  -2.10750165e+02,
#         -1.84305115e+02,  -1.57860064e+02,  -1.31415014e+02,
#         -1.04969963e+02,  -7.85249129e+01,  -5.20798625e+01,
#         -2.56348120e+01,   8.10238427e-01,   2.72552889e+01,
#          5.37003393e+01,   8.01453898e+01,   1.06590440e+02,
#          1.33035491e+02,   1.59480541e+02,   1.85925592e+02,
#          2.12370642e+02,   2.38815693e+02,   2.65260743e+02,
#          2.91705793e+02,   3.18150844e+02,   3.44595894e+02,
#          3.71040945e+02,   3.97485995e+02,   4.23931046e+02,
#          4.50376096e+02,   4.76821147e+02,   5.03266197e+02,
#          5.29711247e+02,   5.56156298e+02,   5.82601348e+02,
#          6.09046399e+02,   6.35491449e+02,   6.61936500e+02,
#          6.88381550e+02,   7.14826601e+02,   7.41271651e+02,
#          7.67716702e+02,   7.94161752e+02,   8.20606802e+02,
#          8.47051853e+02,   8.73496903e+02,   8.99941954e+02,
#          9.26387004e+02,   9.52832055e+02,   9.79277105e+02,
#          1.00572216e+03,   1.03216721e+03,   1.05861226e+03,
#          1.08505731e+03,   1.11150236e+03,   1.13794741e+03,
#          1.16439246e+03,   1.19083751e+03,   1.21728256e+03,
#          1.24372761e+03,   1.27017266e+03,   1.29661771e+03,
#          1.32306276e+03,   1.34950781e+03,   1.37595286e+03,
#          1.40239791e+03,   1.42884296e+03,   1.45528801e+03,
#          1.48173306e+03,   1.50817811e+03,   1.53462316e+03,
#          1.56106822e+03,   1.58751327e+03,   1.61395832e+03,
#          1.64040337e+03,   1.66684842e+03,   1.69329347e+03,
#          1.71973852e+03,   1.74618357e+03,   1.77262862e+03,
#          1.79907367e+03])

# %%
#plt.plot(fhat_dict[0]['domPeak'][0],
#         fhat_dict[0]['domPeak'][1],
#         'rx', label='KDE density peak')
#plt.plot(0, 0, 'ko', fillstyle='none',
#         label='most bound particle')
#plt.legend(loc='best')

pg.plot_KDE_peaks(fhat_dict[0], R200C=R200C[0], showData=True)

# %%
for i in range(10):
    plt.plot(fhat_dict[i]['domPeak'][0],
             fhat_dict[i]['domPeak'][1],
             'rx', label='KDE density peak')
    plt.plot(0, 0, 'ko', fillstyle='none',
             label='most bound particle')
    plt.legend(loc='best')
    plt.title('Cluster {0}'.format(i + 1))
    pg.plot_KDE_peaks(fhat_dict[i], plotdata=False, showData=True,
                      R200C=R200C[i])
    
    plt.close()

# %% [markdown]
# ## Examine super outlier i.e. offset > 2 * R200C

# %%
super_outlier_mask = offset_list[:, 1] > 2.0

# %%
for i in np.arange(0, len(super_outlier_mask), 1)[super_outlier_mask]:
    plt.plot(fhat_dict[i]['domPeak'][0],
             fhat_dict[i]['domPeak'][1],
             'rx', label='KDE density peak')
    plt.plot(0, 0, 'ko', fillstyle='none',
             label='most bound particle')
    plt.legend(loc='best')
    plt.title('Cluster {0} '.format(i + 1) + 
              ' with non-relaxedness {0:.0f}'.format(relaxedness_list[i]))
    pg.plot_KDE_peaks(fhat_dict[i], plotdata=False, showData=True,
                      R200C=R200C[i])
    
    plt.close()

# %%
outlier_mask = np.logical_and(offset_list[:, 1] > 0.5, 
                              offset_list[:, 1] < 2.0)

# %%
fhat_dict[0].keys()
# Out:
# ['gridtype',
#  'bandwidth_matrix_H',
#  'data_x',
#  'gridded',
#  'weight_w',
#  'binned',
#  'names',
#  'domPeak',
#  'eval_points',
#  'estimate']

# %%
for i in np.arange(0, len(outlier_mask), 1)[outlier_mask]:
    plt.plot(fhat_dict[i]['domPeak'][0],
             fhat_dict[i]['domPeak'][1],
             'rx', label='KDE density peak')

    plt.legend(loc='best')
    plt.title('Cluster {0} '.format(i + 1) + 
              ' with non-relaxedness {0:.0f}'.format(relaxedness_list[i]))
    pg.plot_KDE_peaks(fhat_dict[i], plotdata=False, showData=True,
                      R200C=R200C[i], allpeaks=True)
    
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-a552262caf8c> in <module>()
#       8               ' with non-relaxedness {0:.0f}'.format(relaxedness_list[i]))
#       9     pg.plot_KDE_peaks(fhat_dict[i], plotdata=False, showData=True,
# ---> 10                       R200C=R200C[i], allpeaks=True)
#      11
#      12     plt.close()
#
# /Users/karenyng/Documents/Illustris_analysis/code/plot_gal_prop.py in plot_KDE_peaks(fhat, lvls, allpeaks, plotdata, save, R200C, fileName, clabel, showData, xlabel, ylabel)
#     126
#     127     if allpeaks:
# --> 128         for p in fhat["peak_coords_ix"]:
#     129             plt.plot(fhat["eval_points"][0][p[0] - 1],
#     130                      fhat["eval_points"][1][p[1] - 1],
#
# KeyError: 'peak_coords_ix'

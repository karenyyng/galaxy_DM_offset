# %% [markdown]
# This notebook is a basic sanity check of if we extracted the clusters correctly

# %%
# %load_ext autoreload
# %autoreload 2 
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import h5py 
import numpy as np 
import matplotlib.pyplot as plt 
import sys 
sys.path.append("../")

# %%
import extract_catalog as ec

# %%
h5File = \
    "../../data/" + \
    "Illustris-1_fof_subhalo_myCompleteHaloCatalog_00135.hdf5"
f = h5py.File(h5File, "r")

# %%
f.keys()
# Out:
# [u'Group', u'Header', u'Subhalo']

# %%
df_list = [ec.extract_clst(f, cl) for cl in range(10)]

# %%
for i in range(10):
    plt.axes().set_aspect('equal')
    plt.title('cluster {0}'.format(i + 1))
    plt.plot(df_list[i]["SubhaloPos0"], 
             df_list[i]["SubhaloPos1"], '.', alpha=0.1)
    plt.show()
    plt.close()
    plt.axes().set_aspect('equal')
    plt.title('cluster {0}'.format(i + 1))
    plt.plot(df_list[i]["SubhaloPos0"], 
         df_list[i]["SubhaloPos2"], '.', alpha=0.1)
    plt.show()
    plt.close()
    plt.axes().set_aspect('equal')
    plt.title('cluster {0}'.format(i + 1))
    plt.plot(df_list[i]["SubhaloPos1"], 
         df_list[i]["SubhaloPos2"], '.', alpha=0.1)
    plt.show()
    plt.close()

# %%
# %matplotlib inline
# %autoreload 2

# %%
import os
import re
import matplotlib.pyplot as plt
import pandas as pd
import h5py
import sys
import numpy as np

# %%
sys.path.append("../")

# %%
import extract_catalog as ec
import analyze_gal as gal

# %%
data_dir = "../../data/"
data_file = "Illustris-1_fof_subhalo_myCompleteHaloCatalog_00135.hdf5"

# %% [markdown]
# replace this with my faster code that does not require writing out to h5 files

# %%
f = h5py.File(data_dir + data_file, "r")

# %%
# %time dfs = [ec.extract_clst(f, i) for i in range(10)]
# Out:
# CPU times: user 267 ms, sys: 13 s, total: 13.2 s
# Wall time: 13.4 s

# %%
plt.plot(dfs[0]["SubhaloCM0"], dfs[0]["SubhaloCM1"], '.',
         alpha=0.1)

# %%
# %time df = pd.DataFrame(ec.fix_clst_cat(f, 0))
# Out:
# CPU times: user 18.5 ms, sys: 1.11 s, total: 1.13 s
# Wall time: 1.2 s

# %% [markdown]
# there are some catastrophic outliers from the simulation

# %%
map(lambda x: gal.make_color_mag_diag(x, "g_band", "r_band", 15, 
                        plot=True, clst=0, subhalo_len_lim=1e3),
    dfs)
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
f.close()

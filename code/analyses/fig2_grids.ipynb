# %%
# %autoreload 2 
# %matplotlib inline
import h5py
import matplotlib.pyplot as plt
import sys

# %%
sys.path.append("../")

# %%
import compare_peak_methods as compare
import plot_gal_prop as plot_gal

# %%
f = h5py.File("../../data/fig2_data/compare_methods.h5")

# %%
left_col_data = f["50"]

# %%
compare.plot_grid_spec(left_col_data["gauss"],
                       left_col_data["bimodal"],
                       left_col_data["dumb"])

# %%
??plt.contour

# %%
data = left_col_data["gauss"]["KDE"]
dens =  data["estimate"][:]
x = data["eval_points"][:][0]
y = data["eval_points"][:][1]

# %%
lvls
# Out:
# array([ 0.5362885 ,  0.07548152])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, aspect='equal')
cs = plt.contour(x, y, dens.transpose(), lvls)

# %%
p = cs.collections[1].get_paths()[0]
v = p.vertices

# %%
plt.plot(v[:, 0], v[:, 1])

# %%
inside68 = dens[dens > lvls[0]]
mask68 = dens > lvls[0]
mask95 = dens > lvls[1]

# %%
ixes68 = np.array([np.array([i, j]) for j in range(dens.shape[1])
                for i in range(dens.shape[0])
                if mask68[i][j]])
ixes95 = np.array([np.array([i, j]) for j in range(dens.shape[1])
                for i in range(dens.shape[0])
                if mask95[i][j]])

# %%
plt.axes().set_aspect('equal')
plt.plot(x[ixes95[:, 0]], y[ixes95[:, 1]], 'k.')
plt.plot(x[ixes68[:, 0]], y[ixes68[:, 1]], 'b.')

plt.xlim(0, 2.)
plt.ylim(0, 2.)
# Out:
# (0, 2.0)

# %%
# %pfile plt.contour

# %%
coords68 = np.array([x[ixes95[:,0]], y[ixes95[:, 1]]])

# %%
coords68.shape
# Out:
# (2, 5691)

# %%
plt.plot(coords68[0], coords68[1], '.')

# %%
error68 = np.sqrt(np.dot([]))

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# %autoreload 2 
# %matplotlib inline
import h5py
import matplotlib.pyplot as plt
import sys

# %%
sys.path.append("../")

# %%
import compare_peak_methods as compare
import plot_gal_prop as plot_gal

# %%
f = h5py.File("../../data/fig2_data/compare_methods.h5")

# %%
f.keys()
# Out:
# [u'100', u'20', u'50', u'500']

# %%
left_col_data = f["50"]

# %%
f["50/dumb"]["KDE1"]
# Out:
# <HDF5 group "/50/dumb/KDE1" (13 members)>

# %%
output_path = "../../paper/figures/finalized/"
name = "fig3_toy_data_mixtures.eps"

# %% [markdown]
# # To add a legend that is OUTSIDE the plots

# %%
KDE1 = f["50/dumb/KDE1"]

# %%
mask_x = KDE1["eval_points"][:][0] > 0.0
mask_y = KDE1["eval_points"][:][1] > 0.0
start_x_ix = np.arange(len( KDE1["eval_points"][:][0]))[mask_x][0]
start_y_ix = np.arange(len( KDE1["eval_points"][:][1]))[mask_y][0]

# %%
est = KDE1['estimate'][start_x_ix:, start_y_ix:]

# %%
compare.plot_grid_spec(left_col_data["gauss"],
                       left_col_data["bimodal"],
                       left_col_data["dumb"],
                       f, output_path=output_path, 
                       name=name)

# %%
print compare.plot_error_as_a_func_of_data_pts.__doc__

# %%
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.ticker import MaxNLocator

# %%
import sys
sys.path.append("../")

# %%
import compare_peak_methods as com
import plot_gal_prop as pg

# %%
ax =axArr1[0][0]

# %%
ax.legend()

# %%
plt.figure(figsize=(13, 13))
rowNo = 3
colNo = 2
hspace = 0.01

# plot the left two columns
gs1 = gridspec.GridSpec(rowNo, colNo)
gs1.update(left=0.05, right=0.44, wspace=0.01, hspace=hspace)
axArr1 = [[plt.subplot(gs1[i, j], aspect='equal') 
           for j in range(colNo)] for i in range(rowNo)]

# plot the right two columns
gs2 = gridspec.GridSpec(rowNo, colNo)
gs2.update(left=0.51, right=0.98, wspace=0.4, hspace=hspace)
axArr2 = [[plt.subplot(gs2[i, j], aspect='equal') 
           for j in range(colNo)] for i in range(rowNo)]

_ = plt.setp([axArr1[j][1].get_yticklabels()
             for j in range(rowNo)], visible=False)

for j in range(rowNo):
    axArr1[j][1].xaxis.set_major_locator(
        MaxNLocator(nbins=5, prune="lower"))

# %%
gauss_data, bimodal_data, dumb_data = \
    com.read_in_data_for_left_3_cols()

# %%
gauss_data.keys()
# Out:
# [u'KDE', u'shrink', u'cent', u'data']

# %%
gauss_data["data"][:, 0]
# Out:
# array([ 1.65018006,  3.29100388,  1.7043417 ,  2.41733176, -0.0985813 ,
#         1.21663468,  0.47934236,  1.33805008,  1.46508595,  0.20972435,
#         0.21542223,  0.76167445, -1.43279651,  1.84768637,  1.49211925,
#         2.32194218,  0.63346538,  1.35880756,  0.94048785,  0.35667164,
#         1.76363475,  1.93679789,  2.39014536,  2.2751442 ,  0.41571045,
#         1.85145606,  0.1767108 ,  0.09999459,  2.72510725,  1.93634279,
#         0.41054851, -1.00851621,  0.17555553, -0.14201285,  0.40939385,
#         2.27977737,  0.99354304,  1.94055446, -0.94753936, -0.44468945,
#         0.06644474,  1.35777986, -0.28316369,  2.04585871,  0.96056342,
#         0.93385906,  2.91008096,  1.75698237,  1.21089117,  0.65171534])

# %%
com.grid_spec_plot(gauss_data, bimodal_data, dumb_data)
